# %%
# copying public ssh key
# MOUNT DRIVE FIRST
drive_path = '~/../content/drive/MyDrive/DSC/cardiac_challenge_team6'
# %cd $drive_path/ssh
# !ls
# !cat 2023_llnl-dss.pub
# Out:
# /content/drive/MyDrive/DSC/cardiac_challenge_team6/ssh
# 2023_llnl-dss  2023_llnl-dss.pub
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIF1v0RzFV2aWRYpBLKya6jQIQxqlDyW+tMoQN0+O/j/6 root@cd84d0baec05

# %%
# !ls -a
# %cd ~/../content
# !ls -a
# Out:
# 2023_llnl-dss  2023_llnl-dss.pub
# /content
# .  ..  .config	drive  sample_data

# %%
# !mkdir ~/../content/.ssh
# !cp $drive_path/ssh/2023_llnl-dss ~/../content/.ssh/2023_llnl-dss
# !ls -a
# Out:
# mkdir: cannot create directory ‘/root/../content/.ssh’: File exists
# 2023_llnl-dss  2023_llnl-dss.pub

# %%
# !git add .
# !git commit -m "commit msg"
# !git push origin main
# Out:
# [main ed386c3] commit msg
#  2 files changed, 8 insertions(+)
#  create mode 100644 ssh/2023_llnl-dss
#  create mode 100644 ssh/2023_llnl-dss.pub
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.
