# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf

# %%
# copying public ssh key
# MOUNT DRIVE FIRST
drive_path = '~/../content/drive/MyDrive/cardiac_challenge_team6'
# %cd $drive_path/ssh
# !ls
# !cat 2023_llnl-dss.pub
# Out:
# /content/drive/MyDrive/cardiac_challenge_team6/ssh
# 2023_llnl-dss  2023_llnl-dss.pub
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIF1v0RzFV2aWRYpBLKya6jQIQxqlDyW+tMoQN0+O/j/6 root@cd84d0baec05

# %%
# !git rm -r . --cached
# Out:
# fatal: pathspec '.' did not match any files

# %%
data_files = [
    'Task_3_4_Data/\n',
    'intracardiac_dataset/\n',
    'ecg_dataset/\n'
]

with open('.gitignore', 'w') as git_ignore:
  git_ignore.writelines(data_files)

# %%
# %cd $drive_path
# !git add .
# !git diff --name-only --cached
# Out:
# /content/drive/MyDrive/cardiac_challenge_team6
# .gitignore
# notebooks/Copy of task_3_getting_started.ipynb
# notebooks/Zichao Copy of task_3_getting_started.ipynb
# notebooks/task3edits.ipynb
# notebooks/task_1_deep_forest.ipynb
# notebooks/task_1_getting_started.ipynb
# notebooks/task_1_nn.ipynb
# notebooks/task_1_randomforest.ipynb
# notebooks/task_2_GBT.ipynb
# notebooks/task_2_getting_started.ipynb
# notebooks/task_3_getting_started.ipynb
# notebooks/task_4_getting_started.ipynb
# setup_env.ipynb

# %%
# !git commit -m "task1: rf,df,nn task2: knn, gbt,; task3: begin nn"
# !git push origin main
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@6612ce63a6fb.(none)')
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://github.com/brandonator24/cardiac_challenge_team6.git/'

# %%
# Don't run this one
# !git remote rm origin
# !git remote add origin https://brandonator24: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@github.com/brandonator24/cardiac_challenge_team6.git

# %%
# enter your info in the quotes
# !git config --global user.email "brandonpardi24@gmail.com"
# !git config --global user.name "brandonator24"
