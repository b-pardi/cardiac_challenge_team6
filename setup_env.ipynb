# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# copying public ssh key
# MOUNT DRIVE FIRST
drive_path = '~/../content/drive/MyDrive/cardiac_challenge_team6'
# %cd $drive_path/ssh
# !ls
# !cat 2023_llnl-dss.pub
# Out:
# /content/drive/MyDrive/cardiac_challenge_team6/ssh
# 2023_llnl-dss  2023_llnl-dss.pub
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIF1v0RzFV2aWRYpBLKya6jQIQxqlDyW+tMoQN0+O/j/6 root@cd84d0baec05

# %%
# !ls -a
# %cd ~/../content
# !ls -a
# Out:
# 2023_llnl-dss  2023_llnl-dss.pub
# /content
# .  ..  .config	drive  sample_data

# %%
# !cp $drive_path/ssh/2023_llnl-dss ~/.ssh/2023_llnl-dss
# !ls -a
# Out:
# download_intracardiac_dataset.sh  .ipynb_checkpoints  setup_env.ipynb
# ecg_dataset			  LICENSE	      ssh
# figures				  notebooks	      tutorials
# .git				  NOTICE
# .gitignore			  README.md

# %%
# %cd $drive_path
# !git add .
# !git commit -m "commit msg"
# !git push origin main
# Out:
# /content/drive/MyDrive/DSC/cardiac_challenge_team6
# [main d8bbb3d] commit msg
#  2 files changed, 2 insertions(+), 2 deletions(-)
#  rewrite notebooks/task_1_getting_started.ipynb (93%)
# Enumerating objects: 62, done.
# Counting objects: 100% (62/62), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (59/59), done.
# Writing objects: 100% (59/59), 1.75 MiB | 4.52 MiB/s, done.
# Total 59 (delta 37), reused 0 (delta 0)
# remote: Resolving deltas: 100% (37/37), completed with 2 local objects.
# To https://github.com/brandonator24/cardiac_challenge_team6.git
#    6935319..d8bbb3d  main -> main

# %%
# !git remote rm origin
# !git remote add origin https://brandonator24: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@github.com/brandonator24/cardiac_challenge_team6.git

# %%
# !ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
# Out:
# # github.com:22 SSH-2.0-babeld-dc5ec9be
