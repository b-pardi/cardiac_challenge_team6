# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf

# %%
# copying public ssh key
# MOUNT DRIVE FIRST
drive_path = '~/../content/drive/MyDrive/cardiac_challenge_team6'
# %cd $drive_path/ssh
# !ls
# !cat 2023_llnl-dss.pub
# Out:
# /content/drive/MyDrive/cardiac_challenge_team6/ssh
# 2023_llnl-dss  2023_llnl-dss.pub
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIF1v0RzFV2aWRYpBLKya6jQIQxqlDyW+tMoQN0+O/j/6 root@cd84d0baec05

# %%
# !git rm -r . --cached
# Out:
# fatal: pathspec '.' did not match any files

# %%
data_files = [
    'Task_3_4_Data/\n',
    'intracardiac_dataset/\n',
    'ecg_dataset/\n'
]

with open('.gitignore', 'w') as git_ignore:
  git_ignore.writelines(data_files)

# %%
# %cd $drive_path
# !git add .
# !git diff --name-only --cached
# Out:
# /content/drive/MyDrive/cardiac_challenge_team6
# notebooks/task_3_getting_started.ipynb
# setup_env.ipynb

# %%
# !git commit -m "task1: rf,df,nn task2: knn, gbt,; task3: begin nn"
# !git push origin main
# Out:
# [main 7f89797] task1: rf,df,nn task2: knn, gbt,; task3: begin nn
#  2 files changed, 2 insertions(+), 2 deletions(-)
# remote: Permission to brandonator24/cardiac_challenge_team6.git denied to brandonator24.
# fatal: unable to access 'https://github.com/brandonator24/cardiac_challenge_team6.git/': The requested URL returned error: 403

# %%
# Don't run this one
# !git remote rm origin
# !git remote add origin https://brandonator24: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@github.com/brandonator24/cardiac_challenge_team6.git

# %%
# enter your info in the quotes
# !git config --global user.email "brandonpardi24@gmail.com"
# !git config --global user.name "brandonator24"
